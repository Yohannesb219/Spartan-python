# %% [markdown]
# <a href="https://colab.research.google.com/github/Yohannesb219/Spartan-python/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = input("Enter your age:")
x= int(input("Enter your first number:"))
y= int(input("Enter your second number:"))
print("Addition",x+y)
print("Subtraction", x-y)
print("multiplication",x*y)
print("division",x/y)
Print("squared",num*num)
name= input("Enter your name :")
print("keep going, "+ name +" !")
print("you are ,"+ age +",years old you got time !!")
# Out:
# Enter your age:19
